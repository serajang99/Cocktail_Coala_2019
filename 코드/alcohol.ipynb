# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('./final_final_.xlsx')
df
# Out:
#       Unnamed: 0      칵테일명            재료명    개수              단위  oz화개수  \
# 0              0    Mojito      Light Rum   2.5              oz  2.500
# 1              1    Mojito  Juice Of Lime   2.5  half oz(juice)  5.000
# 2              2    Mojito          Sugar   2.0             tsp  0.250
# 3              3    Mojito           Mint   3.0             NaN  0.090
# 4              4    Mojito     Soda Water   1.0             cup  8.000
# ...          ...       ...            ...   ...             ...    ...
# 2288        2288  Spice 75          Sugar  60.0              ml  1.800
# 2289        2289  Spice 75       Allspice   1.0           tblsp  0.375
# 2290        2290  Spice 75            Rum  20.0              cl  6.000
# 2291        2291  Spice 75     Lime Juice  90.0              ml  2.700
# 2292        2292  Spice 75      Champagne   6.0              cl  1.800
#
#         Category       재료비율   ABV    alcohol  alcohol_classification
# 0            Rum  15.782828  40.0        NaN                     NaN
# 1     Ingredient  31.565657   0.0        NaN                     NaN
# 2     Ingredient   1.578283   0.0        NaN                     NaN
# 3     Ingredient   0.568182   0.0        NaN                     NaN
# 4     Ingredient  50.505051   0.0   6.313131                     1.0
# ...          ...        ...   ...        ...                     ...
# 2288  Ingredient  14.201183   0.0        NaN                     NaN
# 2289  Ingredient   2.958580   0.0        NaN                     NaN
# 2290         Rum  47.337278  40.0        NaN                     NaN
# 2291  Ingredient  21.301775   0.0        NaN                     NaN
# 2292   Champagne  14.201183  12.0  20.639053                     2.0
#
# [2293 rows x 11 columns]

# %% [markdown]
# ## 2. EDA & Feature Engineering

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# %%
df['칵테일명'].count()
# Out:
# 2293

# %%
cnt = 0
name = df['칵테일명'][cnt]
print(name)
# Out:
# Mojito

# %%
df['alcohol']=""
df.head()
# Out:
#    Unnamed: 0    칵테일명            재료명   개수              단위  oz화개수    Category  \
# 0           0  Mojito      Light Rum  2.5              oz   2.50         Rum
# 1           1  Mojito  Juice Of Lime  2.5  half oz(juice)   5.00  Ingredient
# 2           2  Mojito          Sugar  2.0             tsp   0.25  Ingredient
# 3           3  Mojito           Mint  3.0             NaN   0.09  Ingredient
# 4           4  Mojito     Soda Water  1.0             cup   8.00  Ingredient
#
#         재료비율   ABV alcohol  alcohol_classification
# 0  15.782828  40.0                             NaN
# 1  31.565657   0.0                             NaN
# 2   1.578283   0.0                             NaN
# 3   0.568182   0.0                             NaN
# 4  50.505051   0.0                             1.0

# %%
cnt2 = 0 
while( cnt != df['칵테일명'].count()):
    sum = 0
    sum2 = 0
    while (df['칵테일명'][cnt] == name):
        #if(df['ABV'][cnt] != 0):
        sum += df['oz화개수'][cnt]
        cnt += 1 
        if(cnt == df['칵테일명'].count()):
            break
    #print(name+":"+str(sum))
    for cnt2 in range(cnt2,cnt,1):
# 2274
# 2278
# 2281
# 2284
# 2287
# 2292

# %%
df
# Out:
#       Unnamed: 0      칵테일명            재료명    개수              단위  oz화개수  \
# 0              0    Mojito      Light Rum   2.5              oz  2.500
# 1              1    Mojito  Juice Of Lime   2.5  half oz(juice)  5.000
# 2              2    Mojito          Sugar   2.0             tsp  0.250
# 3              3    Mojito           Mint   3.0             NaN  0.090
# 4              4    Mojito     Soda Water   1.0             cup  8.000
# ...          ...       ...            ...   ...             ...    ...
# 2288        2288  Spice 75          Sugar  60.0              ml  1.800
# 2289        2289  Spice 75       Allspice   1.0           tblsp  0.375
# 2290        2290  Spice 75            Rum  20.0              cl  6.000
# 2291        2291  Spice 75     Lime Juice  90.0              ml  2.700
# 2292        2292  Spice 75      Champagne   6.0              cl  1.800
#
#         Category       재료비율   ABV  alcohol  alcohol_classification
# 0            Rum  15.782828  40.0                              NaN
# 1     Ingredient  31.565657   0.0                              NaN
# 2     Ingredient   1.578283   0.0                              NaN
# 3     Ingredient   0.568182   0.0                              NaN
# 4     Ingredient  50.505051   0.0  6.31313                     1.0
# ...          ...        ...   ...      ...                     ...
# 2288  Ingredient  14.201183   0.0                              NaN
# 2289  Ingredient   2.958580   0.0                              NaN
# 2290         Rum  47.337278  40.0                              NaN
# 2291  Ingredient  21.301775   0.0                              NaN
# 2292   Champagne  14.201183  12.0  20.6391                     2.0
#
# [2293 rows x 11 columns]

# %%
df = df.drop(["Unnamed: 0"],axis=1)

# %%
df
# Out:
#           칵테일명            재료명    개수              단위  oz화개수    Category  \
# 0       Mojito      Light Rum   2.5              oz  2.500         Rum
# 1       Mojito  Juice Of Lime   2.5  half oz(juice)  5.000  Ingredient
# 2       Mojito          Sugar   2.0             tsp  0.250  Ingredient
# 3       Mojito           Mint   3.0             NaN  0.090  Ingredient
# 4       Mojito     Soda Water   1.0             cup  8.000  Ingredient
# ...        ...            ...   ...             ...    ...         ...
# 2288  Spice 75          Sugar  60.0              ml  1.800  Ingredient
# 2289  Spice 75       Allspice   1.0           tblsp  0.375  Ingredient
# 2290  Spice 75            Rum  20.0              cl  6.000         Rum
# 2291  Spice 75     Lime Juice  90.0              ml  2.700  Ingredient
# 2292  Spice 75      Champagne   6.0              cl  1.800   Champagne
#
#            재료비율   ABV  alcohol  alcohol_classification
# 0     15.782828  40.0                              NaN
# 1     31.565657   0.0                              NaN
# 2      1.578283   0.0                              NaN
# 3      0.568182   0.0                              NaN
# 4     50.505051   0.0  6.31313                     1.0
# ...         ...   ...      ...                     ...
# 2288  14.201183   0.0                              NaN
# 2289   2.958580   0.0                              NaN
# 2290  47.337278  40.0                              NaN
# 2291  21.301775   0.0                              NaN
# 2292  14.201183  12.0  20.6391                     2.0
#
# [2293 rows x 10 columns]

# %%
df.to_excel("final_final_3.xlsx")
