# %% [markdown]
# # 데이터를 불러옵니다.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("./Data가공/fffffinal_5.xlsx")
df = df.drop(["Unnamed: 0"],axis=1)
df.head(10)
# Out:
#               칵테일명                재료명   개수              단위    oz화개수  \
# 0           Mojito          Light Rum  2.5              oz  2.50000
# 1           Mojito      Juice Of Lime  2.5  half oz(juice)  5.00000
# 2           Mojito              Sugar  2.0             tsp  0.25000
# 3           Mojito               Mint  3.0             NaN  0.09000
# 4           Mojito         Soda Water  1.0             cup  8.00000
# 5    Old Fashioned            Bourbon  4.5              cl  1.35000
# 6    Old Fashioned  Angostura Bitters  2.0            dash  0.06250
# 7    Old Fashioned              Sugar  1.0            cube  0.06000
# 8    Old Fashioned              Water  1.0            dash  0.03125
# 9  Long Island Tea              Vodka  0.5              oz  0.50000
#
#      Category       재료비율   ABV    alcohol  alcohol_classification  \
# 0         Rum  15.782828  40.0        NaN                     NaN
# 1  Ingredient  31.565657   0.0        NaN                     NaN
# 2  Ingredient   1.578283   0.0        NaN                     NaN
# 3  Ingredient   0.568182   0.0        NaN                     NaN
# 4  Ingredient  50.505051   0.0   6.313131                     1.0
# 5     Whiskey  89.775561  40.0        NaN                     NaN
# 6     Liqueur   4.156276  44.7        NaN                     NaN
# 7  Ingredient   3.990025   0.0        NaN                     NaN
# 8  Ingredient   2.078138   0.0  37.768080                     3.0
# 9       Vodka  16.494845  40.0        NaN                     NaN
#
#    ingrid_classification
# 0                    NaN
# 1                    1.0
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN

# %%
df.describe()
# Out:
#                 개수        oz화개수         재료비율          ABV     alcohol  \
# count  2293.000000  2293.000000  2293.000000  2293.000000  592.000000
# mean      5.643480     3.449650    25.817706    15.302268   16.493787
# std      61.782682     9.297269    22.827404    18.178120   11.844864
# min       0.120000     0.006670     0.019848     0.000000    0.000000
# 25%       1.000000     0.450000     7.165605     0.000000    6.956522
# 50%       1.000000     1.000000    20.000000     0.000000   14.000000
# 75%       2.000000     3.000000    37.837838    39.000000   25.505556
# max    1750.000000   132.000000    99.843305    95.000000   50.333333
#
#        alcohol_classification  ingrid_classification
# count              592.000000             671.000000
# mean                 1.523649               2.078987
# std                  1.091165               1.264211
# min                  0.000000               0.000000
# 25%                  1.000000               1.000000
# 50%                  1.000000               2.000000
# 75%                  3.000000               4.000000
# max                  3.000000               4.000000

# %% [markdown]
# # EDA 및 Feature Engineering을 실시합니다.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# %%
facet = sns.FacetGrid(df, aspect=4)
facet.map(sns.kdeplot, 'alcohol')
facet.add_legend()

plt.show()
