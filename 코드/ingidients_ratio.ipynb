# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('./cocktail_data_categorized_ingredient_Ver.3.xlsx')
df
# Out:
#       Unnamed: 0      칵테일명            재료명    개수              단위  oz화개수  \
# 0              0    Mojito      Light Rum   2.5              oz  2.500
# 1              1    Mojito  Juice Of Lime   2.5  half oz(juice)  5.000
# 2              2    Mojito          Sugar   2.0             tsp  0.250
# 3              3    Mojito           Mint   3.0             NaN  0.090
# 4              4    Mojito     Soda Water   1.0             cup  8.000
# ...          ...       ...            ...   ...             ...    ...
# 2288        2288  Spice 75          Sugar  60.0              ml  1.800
# 2289        2289  Spice 75       Allspice   1.0           tblsp  0.375
# 2290        2290  Spice 75            Rum  20.0              cl  6.000
# 2291        2291  Spice 75     Lime Juice  90.0              ml  2.700
# 2292        2292  Spice 75      Champagne   6.0              cl  1.800
#
#         Category
# 0            Rum
# 1     Ingredient
# 2     Ingredient
# 3     Ingredient
# 4     Ingredient
# ...

# %% [markdown]
# ## 2. EDA & Feature Engineering

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# %%
grouped = df["oz화개수"].groupby(df["칵테일명"])
grouped

# %%
grouped.describe()
# Out:
#                                       count      mean        std      min  \
# 칵테일명
# '57 Chevy with a White License Plate    2.0  1.000000   0.000000  1.00000
# 1-900-FUK-MEUP                          8.0  0.312500   0.115728  0.25000
# 110 in the shade                        2.0  8.750000  10.253048  1.50000
# 151 Florida Bushwacker                  8.0  1.937500   2.583429  0.50000
# 155 Belmont                             4.0  4.375000   1.750000  3.50000
# ...                                     ...       ...        ...      ...
# Zizi Coin-coin                          4.0  1.710000   1.934011  0.24000
# Zoksel                                  7.0  5.071429   2.921594  1.00000
# Zombie                                  7.0  0.625953   0.683642  0.00667
# Zorbatini                               2.0  0.750000   0.707107  0.25000
# Zorro                                   3.0  0.600000   0.000000  0.60000
#
#                                         25%    50%      75%    max
# 칵테일명
# ...

# %%
df['칵테일명'].count()
# Out:
# 2293

# %%
cnt = 0
name = df['칵테일명'][cnt]
print(name)
# Out:
# Mojito

# %%
cnt2 = 0 
while( cnt != df['칵테일명'].count()):
    sum = 0
    while (df['칵테일명'][cnt] == name):
        sum += df['oz화개수'][cnt]
        cnt += 1 
        if(cnt == df['칵테일명'].count()):
            break
    print(name+":"+str(sum))
    for cnt2 in range(cnt2,cnt,1):
        df['재료비율'][cnt2] = df['oz화개수'][cnt2]/sum*100
        #print(sum)
    cnt2=cnt
    if(cnt == df['칵테일명'].count()):
        break
    else:
        name = df['칵테일명'][cnt]
# Out:
# Mojito:15.84
# Old Fashioned:1.5037500000000001
# Long Island Tea:3.03125
# Negroni:3.0
# Whiskey Sour:3.5124999999999997
# Dry Martini:2.15
# Daiquiri:2.625
# Margarita:3.06
# Manhattan:3.659375
# Moscow Mule:12.0
# After Dinner Cocktail:8.5
# After Supper Cocktail:2.0625
# Alabama Slammer:2.53125
# Alaska Cocktail:2.3125
# Alexander:3.35
# Brandy Alexander:3.35
# Alfie Cocktail:1.90625
# Algonquin:3.5
# Allegheny:2.375
# Allies Cocktail:2.0625
# Almeria:3.9
# Almond Joy:3.0
# Amaretto And Cream:3.0
# Amaretto Mist:6.0
# Amaretto Rose:10.0
# Amaretto Stinger:2.25
# Amaretto Tea:9.7
# Angel Face:2.0
# Applecar:3.0
# Apricot Lady:8.525
# Archbishop:7.625
# Arise My Love:1.125
# Arthur Tompkins:2.75
# Artillery:1.75
# Balmoral:2.5625
# Banana Daiquiri:7.8
# Bermuda Highball:10.25
# Black Russian:2.25
# Blackthorn:2.5
# Bloody Maria:3.39375
# Bloody Mary:4.910425
# Blue Lagoon:10.3
# Blue Margarita:3.56
# Blue Mountain:3.625
# Bluebird:2.8625
# Bobby Burns Cocktail:3.15625
# ...

# %%
df
# Out:
#       Unnamed: 0      칵테일명            재료명    개수              단위  oz화개수  \
# 0              0    Mojito      Light Rum   2.5              oz  2.500
# 1              1    Mojito  Juice Of Lime   2.5  half oz(juice)  5.000
# 2              2    Mojito          Sugar   2.0             tsp  0.250
# 3              3    Mojito           Mint   3.0             NaN  0.090
# 4              4    Mojito     Soda Water   1.0             cup  8.000
# ...          ...       ...            ...   ...             ...    ...
# 2288        2288  Spice 75          Sugar  60.0              ml  1.800
# 2289        2289  Spice 75       Allspice   1.0           tblsp  0.375
# 2290        2290  Spice 75            Rum  20.0              cl  6.000
# 2291        2291  Spice 75     Lime Juice  90.0              ml  2.700
# 2292        2292  Spice 75      Champagne   6.0              cl  1.800
#
#         Category       재료비율
# 0            Rum  15.782828
# 1     Ingredient  31.565657
# ...

# %%
df.drop(["Unnamed: 0"],axis=1)
# Out:
#           칵테일명            재료명    개수              단위  oz화개수    Category  \
# 0       Mojito      Light Rum   2.5              oz  2.500         Rum
# 1       Mojito  Juice Of Lime   2.5  half oz(juice)  5.000  Ingredient
# 2       Mojito          Sugar   2.0             tsp  0.250  Ingredient
# 3       Mojito           Mint   3.0             NaN  0.090  Ingredient
# 4       Mojito     Soda Water   1.0             cup  8.000  Ingredient
# ...        ...            ...   ...             ...    ...         ...
# 2288  Spice 75          Sugar  60.0              ml  1.800  Ingredient
# 2289  Spice 75       Allspice   1.0           tblsp  0.375  Ingredient
# 2290  Spice 75            Rum  20.0              cl  6.000         Rum
# 2291  Spice 75     Lime Juice  90.0              ml  2.700  Ingredient
# 2292  Spice 75      Champagne   6.0              cl  1.800   Champagne
#
#            재료비율
# 0     15.782828
# 1     31.565657
# 2      1.578283
# 3      0.568182
# 4     50.505051
# ...

# %%
df.to_excel("new.xlsx")
